# %%
import tensorflow as tf

for example in tf.compat.v1.python_io.tf_record_iterator("default.tfrecord"):
    print(tf.train.Example.FromString(example))
# Out:
# features {
#   feature {
#     key: "image/encoded"
#     value {
#       bytes_list {
#         value: ""
#       }
#     }
#   }
#   feature {
#     key: "image/filename"
#     value {
#       bytes_list {
#         value: "frame_000000.jpg"
#       }
#     }
#   }
#   feature {
#     key: "image/format"
#     value {
#       bytes_list {
#         value: ""
#       }
#     }
#   }
#   feature {
#     key: "image/height"
#     value {
#       int64_list {
#         value: 892
#       }
#     }
#   }
#   feature {
#     key: "image/key/sha256"
#     value {
#       bytes_list {
#         value: ""
#       }
#     }
#   }
#   feature {
#     key: "image/object/bbox/xmax"
#     value {
#       float_list {
#         value: 0.34645912051200867
#         value: 0.5679082274436951
#       }
#     }
#   }
#   feature {
#     key: "image/object/bbox/xmin"
#     value {
#       float_list {
#         value: 0.28736090660095215
#         value: 0.5088100433349609
#       }
#     }
#   }
# ...
